# %%
# %pylab inline

import os
import glob
import numpy as np
import astropy.table as astTable
import matplotlib.pyplot as plt
import xlens
import warnings
warnings.filterwarnings('ignore')
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
pwd
# Out:
# '/work/xiangchong.li/superonionGW/code/hsc_final/HSC_S23B_Shapes/notebook/1_prepare_sim'

# %%
tract_list = [10054, 10055, 9570, 9571]
#tract_list = [10055, 9570]

flux_sim =  []
fwhm_sim = []
var_sim = []
size_sim = []

for tract in tract_list:
    tract_dir = "/work/xiangchong.li/work/hsc_s23b_sim/sim_cosmos/cosmos/dm_catalog33/20250208T204339Z/sim_2_rot0_Coadd_meas/%s/" % (tract)
    sub_dirs = glob.glob(tract_dir + "/*")
    for patch_dir in sub_dirs:
        if len(glob.glob(patch_dir+ "/*")) < 5:
            continue
        file_name = glob.glob(patch_dir + "/i/*")[0]
        data = astTable.Table.read(file_name, hdu=1).as_array().data
        data = data[data["deblend_nChild"] == 0 & (data["base_ClassificationExtendedness_value"]>0)]
        flux_sim.append(data["modelfit_CModel_instFlux"])
        fwhm_sim.append(xlens.catalog.basic.get_psf_size(data, pixel_scale=0.168))
        var_sim.append(data["base_Variance_value"])
        size_sim.append(xlens.catalog.basic.get_sdss_size(data))
flux_sim = np.hstack(flux_sim)
fwhm_sim = np.hstack(fwhm_sim)
var_sim = np.hstack(var_sim)
size_sim = np.hstack(size_sim)
size_sim0 = size_sim

# %%
flux_data =  []
fwhm_data = []
var_data = []
size_data = []
for tract in tract_list:
    tract_dir = "/lustre/HSC_DR/hsc_ssp/dr4/s23b/data/s23b_wide/unified/deepCoadd_meas/%s" % (tract)
    sub_dirs = glob.glob(tract_dir + "/*")
    for patch_dir in sub_dirs:
        if len(glob.glob(patch_dir+ "/*")) < 5:
            continue
        file_name = glob.glob(patch_dir + "/i/*")[0]
        data = astTable.Table.read(file_name, hdu=1).as_array().data
        data = data[data["deblend_nChild"] == 0 & (data["base_ClassificationExtendedness_value"]>0)]
        flux_data.append(data["modelfit_CModel_instFlux"])
        fwhm_data.append(xlens.catalog.basic.get_psf_size(data, pixel_scale=0.168))
        var_data.append(data["base_Variance_value"])
        size_data.append(xlens.catalog.basic.get_sdss_size(data))
flux_data = np.hstack(flux_data)
fwhm_data = np.hstack(fwhm_data)
var_data = np.hstack(var_data)
size_data = np.hstack(size_data)

# %%
flux_sim_g = []
flux_sim_r = []
flux_sim_z = []
flux_sim_y = []
for tract in tract_list:
    tract_dir = "/work/xiangchong.li/work/hsc_s23b_sim/sim_cosmos/cosmos/dm_catalog33/20250208T204339Z/sim_2_rot0_Coadd_meas/%s/" % (tract)
    sub_dirs = glob.glob(tract_dir + "/*")
    for patch_dir in sub_dirs:
        if len(glob.glob(patch_dir+ "/*")) < 5:
            continue
        file_name = glob.glob(patch_dir + "/g/*")[0]
        data = astTable.Table.read(file_name, hdu=1).as_array().data
        data = data[data["deblend_nChild"] == 0& (data["base_ClassificationExtendedness_value"] > 0)]
        flux_sim_g.append(data["modelfit_CModel_instFlux"])
            
        file_name = glob.glob(patch_dir + "/r/*")[0]
        data = astTable.Table.read(file_name, hdu=1).as_array().data
        data = data[data["deblend_nChild"] == 0& (data["base_ClassificationExtendedness_value"] > 0)]
        flux_sim_r.append(data["modelfit_CModel_instFlux"])
        
        file_name = glob.glob(patch_dir + "/z/*")[0]
        data = astTable.Table.read(file_name, hdu=1).as_array().data
        data = data[data["deblend_nChild"] == 0& (data["base_ClassificationExtendedness_value"] > 0)]
        flux_sim_z.append(data["modelfit_CModel_instFlux"])
        
        file_name = glob.glob(patch_dir + "/y/*")[0]
        data = astTable.Table.read(file_name, hdu=1).as_array().data
        data = data[data["deblend_nChild"] == 0& (data["base_ClassificationExtendedness_value"] > 0)]
        flux_sim_y.append(data["modelfit_CModel_instFlux"])
flux_sim_g = np.hstack(flux_sim_g)
flux_sim_r = np.hstack(flux_sim_r)
flux_sim_z = np.hstack(flux_sim_z)
flux_sim_y = np.hstack(flux_sim_y)

# %%
flux_data_g = []
flux_data_r = []
flux_data_z = []
flux_data_y = []
for tract in tract_list:
    tract_dir = "/lustre/HSC_DR/hsc_ssp/dr4/s23b/data/s23b_wide/unified/deepCoadd_meas/%s" % (tract)
    sub_dirs = glob.glob(tract_dir + "/*")
    for patch_dir in sub_dirs:
        if len(glob.glob(patch_dir+ "/*")) < 5:
            continue
        file_name = glob.glob(patch_dir + "/g/*")[0]
        data = astTable.Table.read(file_name, hdu=1).as_array().data
        data = data[data["deblend_nChild"] == 0& (data["base_ClassificationExtendedness_value"]>0)]
        flux_data_g.append(data["modelfit_CModel_instFlux"])
        
        file_name = glob.glob(patch_dir + "/r/*")[0]
        data = astTable.Table.read(file_name, hdu=1).as_array().data
        data = data[data["deblend_nChild"] == 0& (data["base_ClassificationExtendedness_value"]>0)]
        flux_data_r.append(data["modelfit_CModel_instFlux"])
        
        file_name = glob.glob(patch_dir + "/z/*")[0]
        data = astTable.Table.read(file_name, hdu=1).as_array().data
        data = data[data["deblend_nChild"] == 0& (data["base_ClassificationExtendedness_value"]>0)]
        flux_data_z.append(data["modelfit_CModel_instFlux"])
        
        file_name = glob.glob(patch_dir + "/y/*")[0]
        data = astTable.Table.read(file_name, hdu=1).as_array().data
        data = data[data["deblend_nChild"] == 0& (data["base_ClassificationExtendedness_value"]>0)]
        flux_data_y.append(data["modelfit_CModel_instFlux"])
flux_data_g = np.hstack(flux_data_g)
flux_data_r = np.hstack(flux_data_r)
flux_data_z = np.hstack(flux_data_z)
flux_data_y = np.hstack(flux_data_y)

# %%
def get_mag(flux):
    return 27.0 - np.log10(flux) * 2.5
    
def scale_factor(mag):
    if mag < 21:
        return 1.08
    elif mag < 25:
        return 1.06 - 0.05 * (mag-21)
    else:
        return 0.88
        
mag_sim = get_mag(flux_sim)
mag_data = get_mag(flux_data)

mag_sim_g = get_mag(flux_sim_g)
mag_data_g = get_mag(flux_data_g)

mag_sim_r = get_mag(flux_sim_r)
mag_data_r = get_mag(flux_data_r)

mag_sim_z = get_mag(flux_sim_z)
mag_data_z = get_mag(flux_data_z)

mag_sim_y = get_mag(flux_sim_y)
mag_data_y = get_mag(flux_data_y)
size_sim = size_sim0 #* np.vectorize(scale_factor)(mag_sim)

mag_lim = 25.0
mag_lim2 = 26.0
size_lim = 0.3

msk_sim =  (mag_sim < mag_lim) & (size_sim > size_lim) & (mag_sim_g < mag_lim2) & (mag_sim_r < mag_lim) & (mag_sim_z < mag_lim) & (mag_sim_y < mag_lim2)
msk_data =  (mag_data< mag_lim) & (size_data > size_lim) & (mag_data_g< mag_lim2) & (mag_data_r< mag_lim) & (mag_data_z< mag_lim) & (mag_data_y< mag_lim2)

# %%
plt.close()
plt.hist(mag_data, bins=30, range=(20, 27), histtype="step", density =True, color="black", label="Data")
plt.hist(mag_sim, bins=30, range=(20, 27), histtype="step", density=True, color="black", linestyle="--", label="Sim")
plt.legend()
plt.xlabel(r"$i$ magnitude")
plt.ylabel("PDF")

# %%
plt.hist(mag_data_r[msk_data], bins=30, range=(20, 28), histtype="step", density =True, color="black", label="Data")
plt.hist(mag_sim_r[msk_sim], bins=30, range=(20, 28), histtype="step", density=True, color="black", label="Sim", linestyle="--")
plt.legend()
plt.xlabel(r"$r$ magnitude")
plt.ylabel("PDF")

# %%
plt.hist(mag_data_z[msk_data], bins=30, range=(20, 28), histtype="step", density =True, color="black", label="Data")
plt.hist(mag_sim_z[msk_sim], bins=30, range=(20, 28), histtype="step", density=True, color="black", label="Sim", linestyle="--")
plt.legend()
plt.xlabel(r"$z$ magnitude")
plt.ylabel("PDF")

# %%
plt.close()
plt.hist(size_sim, bins=30, histtype="step", density=True, range=(0.2, 1.2), color="black", label="Sim", linestyle="--")
plt.hist(size_data, bins=30, histtype="step", density =True, range=(0.2, 1.2), color="black", label="Data")
plt.xlabel("i band size [arcsec]")
plt.ylabel("PDF")
plt.legend()

# %%
plt.close()
msks = mag_sim < 22
mskd = mag_data < 22
plt.hist(size_sim[msks] * 1.05, bins=30, histtype="step", density=True, range=(0.3, 1.2), color="black", label="Sim", linestyle="--")
plt.hist(size_data[mskd], bins=30, histtype="step", density =True, range=(0.3, 1.2), color="black", label="Data")
plt.xlabel("i band size [arcsec]")
plt.ylabel("PDF")
plt.legend()

# %%
plt.close()
msks = (mag_sim > 22) & (mag_sim < 24) 
mskd = (mag_data > 22) & (mag_data < 24)
plt.hist(size_sim[msks], bins=30, histtype="step", density=True, range=(0.3, 1.2), color="black", label="Sim", linestyle="--")
plt.hist(size_data[mskd], bins=30, histtype="step", density =True, range=(0.3, 1.2), color="black", label="Data")
plt.xlabel("i band size [arcsec]")
plt.ylabel("PDF")
plt.legend()

# %%
plt.close()
msks = (mag_sim > 24) & (mag_sim < 26) 
mskd = (mag_data > 24) & (mag_data < 26)
plt.hist(size_sim[msks] / 1.1, bins=30, histtype="step", density=True, range=(0.3, 1.2), color="black", label="Sim", linestyle="--")
plt.hist(size_data[mskd], bins=30, histtype="step", density =True, range=(0.3, 1.2), color="black", label="Data")
plt.xlabel("i band size [arcsec]")
plt.ylabel("PDF")
plt.legend()

# %%
plt.close()
plt.hist(var_sim[msk_sim], bins=30, histtype="step", density=True, range=(1e-3, 1e-2), color="black", label="Sim", linestyle="--")
plt.hist(var_data[msk_data], bins=30, histtype="step", density =True, range=(1e-3, 1e-2), color="black", label="Data", linestyle="-")
print(np.nanmean(var_sim[msk_sim]) / np.nanmean(var_data[msk_data]))
plt.xlabel("noise variance")
plt.ylabel("PDF")
plt.legend()

# %%
plt.close()
plt.hist(fwhm_sim, bins=30, histtype="step", density=True, range=(0.4, 0.9), color="black", label="Sim", linestyle="--")
plt.hist(fwhm_data, bins=30, histtype="step", density =True, range=(0.4, 0.9), color="black", label="Data", linestyle="--")
plt.xlabel("PSF FWHM [arcsec]")
plt.ylabel("PDF")

# %%
class corner_plot:
    def __init__(self, xrange, yrange, bins=30, xlabel="x", ylabel="y", xlim=None, ylim=None):
        fig = plt.figure(figsize=(8, 8))
        gs = fig.add_gridspec(4, 4, wspace=0.05, hspace=0.05)
        # 2D Contour plot (central plot)
        self.ax_2d = fig.add_subplot(gs[1:4, 0:3])
        self.ax_2d.set_xlabel(xlabel)
        self.ax_2d.set_ylabel(ylabel)
        
        self.ax_top = fig.add_subplot(gs[0, 0:3], sharex=self.ax_2d)
        self.ax_top.set_ylabel('PDF')
        self.ax_top.tick_params(axis="x", labelbottom=False)
        
        self.ax_right = fig.add_subplot(gs[1:4, 3], sharey=self.ax_2d)
        self.ax_right.set_xlabel('PDF')
        self.ax_right.tick_params(axis="y", labelleft=False)
        
        self.range_2d = [xrange, yrange]
        self.range_x = xrange
        self.range_y = yrange
        self.bins = bins

        if xlim is None:
            xlim = self.range_x
            
        if ylim is None:
            ylim = self.range_y
        self.ax_2d.set_xlim(xlim)
        self.ax_2d.set_ylim(ylim)
        self.ax_top.set_xlim(xlim)
        self.ax_right.set_ylim(ylim)
        return

    def make_plot(self, x_array, y_array, w_array=None, linestyles="-", levels=[0.1, 0.3, 0.6]):
        # Create figure and gridspec
        hist, xedges, yedges = np.histogram2d(
            x=x_array, y=y_array, bins=self.bins,
            range=self.range_2d,
            density=True,
            weights=w_array,
        )
        # Calculate the midpoints of bins
        xcenters = 0.5 * (xedges[:-1] + xedges[1:])
        ycenters = 0.5 * (yedges[:-1] + yedges[1:])
        X, Y = np.meshgrid(xcenters, ycenters)
        
        # Contour plot
        contour = self.ax_2d.contour(
            X, Y, hist.T, levels=levels, 
            colors="black", linestyles=linestyles,
        )
        
        # 1D Histogram (top plot)
        self.ax_top.hist(x_array, bins=self.bins, histtype='step', color='black', 
            range=self.range_x, density=True, ls=linestyles, weights=w_array,
        )
        
        # 1D Histogram (right plot)
        self.ax_right.hist(y_array, bins=self.bins, histtype='step', color='black', 
            range=self.range_y, density=True, 
            ls=linestyles, orientation='horizontal', 
            weights=w_array,
        )
        
        # Final adjustments
        plt.tight_layout()

# %%
plt.close()
xrange = [20.0, 26.0]
yrange = [-0.4, 1.1]
xlabel = r'$i$ magnitude'
ylabel = r'$r$ - $i$'

corp = corner_plot(
    xrange=xrange, yrange=yrange, bins=30, xlabel=xlabel, ylabel=ylabel,
    xlim=[20, 26.2], ylim=[-0.4, 1.1]
)

x_array = mag_sim[msk_sim]
y_array = mag_sim_r[msk_sim] - mag_sim[msk_sim]

x_array_d = mag_data[msk_data]
y_array_d = mag_data_r[msk_data] - mag_data[msk_data]

corp.make_plot(x_array=x_array_d, y_array=y_array_d, linestyles="-",  levels=[0.1, 0.3, 0.65])
corp.make_plot(x_array=x_array, y_array=y_array, linestyles="--",  levels=[0.1, 0.3, 0.65])

# %%
plt.close()

xrange = [20.0, 26.0]
yrange = [-0.5, 1.0]
xlabel = r'$i$ magnitude'
ylabel = r'$i$ - $z$'

corp = corner_plot(
    xrange=xrange, yrange=yrange, bins=30, xlabel=xlabel, ylabel=ylabel,
    xlim=[20, 26.2], ylim=[-0.5, 1.05]
)

x_array = mag_sim[msk_sim]
y_array = mag_sim[msk_sim] - mag_sim_z[msk_sim]

x_array_d = mag_data[msk_data]
y_array_d = mag_data[msk_data] - mag_data_z[msk_data]

corp.make_plot(x_array=x_array_d, y_array=y_array_d, linestyles="-", levels=[0.15, 0.3, 0.65])
corp.make_plot(x_array=x_array, y_array=y_array, linestyles="--", levels=[0.15, 0.3, 0.65])

# %%
plt.close()

xrange = [20., 26.2]
yrange = [0.2, 1.2]
xlabel = r'$i$ magnitude'
ylabel = r'$i$-band size [arcsec]'
corp = corner_plot(
    xrange=xrange, yrange=yrange, bins=30, xlabel=xlabel, ylabel=ylabel,
    xlim=[20., 26.2], ylim=[0.2, 1.06]
)

x_array = mag_sim[msk_sim]
y_array = size_sim[msk_sim]

x_array_d = mag_data[msk_data]
y_array_d = size_data[msk_data]

corp.make_plot(x_array=x_array_d, y_array=y_array_d, linestyles="-")
corp.make_plot(x_array=x_array, y_array=y_array, linestyles="--")

# %%
def scale_factor(mag):
    if mag < 21:
        return 1.08
    elif mag < 25:
        return 1.08 - 0.06 * (mag-21)
    else:
        return 0.84
dd = pyfits.getdata("/home/xiangchong.li/Downloads/catsim-v2/OneDegSq.fits")
print(len(dd))
ratio = np.vectorize(scale_factor)(dd["i_ab"])
for nn in ["a_b", "a_d", "b_b", "b_d"]:
    dd[nn] = dd[nn] * ratio
pyfits.writeto("/home/xiangchong.li/Downloads/catsim-v3/OneDegSq.fits", dd, overwrite=True)
print(len(dd))

# %%
mlim = 25.0
catsim = pyfits.getdata("/home/xiangchong.li/Downloads/catsim-v3/OneDegSq.fits")
print(len(catsim))
sel = (catsim["g_ab"] < mlim) & (catsim["r_ab"] < mlim) & (catsim["i_ab"] < mlim) & (catsim["z_ab"] < mlim) & (catsim["y_ab"] < mlim)
catsim = catsim[sel]
des = pyfits.getdata("/home/xiangchong.li/input_cosmos_v2.1.fits")
sel = (des["mag_g"] < mlim) & (des["mag_r"] < mlim) & (des["mag_i"] < mlim) & (des["mag_z"] < mlim) & (des["mag_y"] < mlim)
des = des[sel]

# %%
plt.close()
xrange = [-1.0, 26.0]
yrange = [-0.5, 2.0]
xlabel = r'$i$ magnitude'
ylabel = r'$r$ - $i$'

corp = corner_plot(
    xrange=xrange, yrange=yrange, bins=30, xlabel=xlabel, ylabel=ylabel,
    xlim=[20, 26], ylim=[-0.5, 2.05]
)

x_array = catsim["i_ab"]
y_array = catsim["g_ab"] - catsim["r_ab"]

x_array_d = des["mag_i"]
y_array_d = des["mag_g"] - des["mag_r"]

corp.make_plot(x_array=x_array_d, y_array=y_array_d, linestyles="-",  levels=[0.1, 0.3, 0.65])
corp.make_plot(x_array=x_array, y_array=y_array, linestyles="--",  levels=[0.1, 0.3, 0.65])

# %%
plt.hist(des["z"], density=True, histtype="step")
plt.hist(catsim["redshift"], density=True, histtype="step")

# %%
from minisom import MiniSom
bands="grizy"
d_sim = np.vstack([catsim["%s_ab" %a] for a in bands]).T
d_data = np.vstack([des["mag_%s" %a] for a in bands]).T

data_min = np.min(d_data, axis=0)
data_max = np.max(d_data,axis=0)
d_norm_data = (d_data - data_min) / (data_max - data_min)
d_norm_sim = (d_sim - data_min) / (data_max - data_min)

# %%
som_size = (30, 30)
som = MiniSom(som_size[0], som_size[1], 5, sigma=0.1, learning_rate=1)

# Step 4: Train the SOM
print("Training SOM...")
som.random_weights_init(d_norm_data)
som.train_random(d_norm_data, 1000)  # Train for 1000 iterations
print("Training complete!")
print(som.winner(d_norm_data[2]))

# %%
plt.close()
mapped_data = np.array([som.winner(d) for d in d_norm_data])
plt.close()
hist_data = plt.hist2d(
    mapped_data[:, 0], 
    mapped_data[:, 1], 
    bins=(np.arange(-0.5, som_size[0], 1), np.arange(-0.5, som_size[1], 1)),
    density=True,
)[0]

# %%
plt.close()
mapped_sim = np.array([som.winner(d) for d in d_norm_sim])
plt.close()
hist_sim=plt.hist2d(
    mapped_sim[:, 0], 
    mapped_sim[:, 1], 
    bins=(np.arange(-0.5, som_size[0], 1), np.arange(-0.5, som_size[1], 1)),
    density=True,
)[0]

# %%
weight_hist = hist_data / (hist_sim )
weight_hist[np.isinf(weight_hist)] = 1.0
weight_hist[weight_hist > 10] = 10.0
weight_hist[weight_hist < 0.1] = 0.1

mapped_sim_id = som_size[1] * mapped_sim[:, 0] + mapped_sim[:, 1]
weights = weight_hist.flatten()[mapped_sim_id]

# %%
plt.hist(np.log10(weights))

# %%
plt.close()
xrange = [-1.0, 26.0]
yrange = [-0.5, 2.0]
xlabel = r'$i$ magnitude'
ylabel = r'$r$ - $i$'

corp = corner_plot(
    xrange=xrange, yrange=yrange, bins=30, xlabel=xlabel, ylabel=ylabel,
    xlim=[20, 26], ylim=[-0.5, 2.05]
)

x_array = catsim["i_ab"]
y_array = catsim["g_ab"] - catsim["r_ab"]

x_array_d = des["mag_i"]
y_array_d = des["mag_g"] - des["mag_r"]

corp.make_plot(x_array=x_array_d, y_array=y_array_d, linestyles="-",  levels=[0.1, 0.3, 0.65])
corp.make_plot(x_array=x_array, y_array=y_array, w_array=weights, linestyles="--",  levels=[0.1, 0.3, 0.65])

# %%
plt.hist(des["z"], density=True, histtype="step")
plt.hist(catsim["redshift"], density=True, histtype="step", weights=weights)

# %%
catsim = astTable.Table.read("/home/xiangchong.li/Downloads/catsim-v3/OneDegSq.fits")
print(len(catsim))
sel = (catsim["g_ab"] < mlim) & (catsim["r_ab"] < mlim) & (catsim["i_ab"] < mlim) & (catsim["z_ab"] < mlim) & (catsim["y_ab"] < mlim)
catsim["prob"] = 1.0
catsim["prob"][sel] = weights
catsim["prob"] = catsim["prob"] / np.average(catsim["prob"])
print(len(catsim))
catsim.write("/home/xiangchong.li/Downloads/catsim-v4/OneDegSq.fits", overwrite=True)

# %%
# Tests
catsim = astTable.Table.read("/work/xiangchong.li/superonionGW/code/image/catsim-v4/OneDegSq.fits")
sel = (catsim["g_ab"] < mlim) & (catsim["r_ab"] < mlim) & (catsim["i_ab"] < mlim) & (catsim["z_ab"] < mlim) & (catsim["y_ab"] < mlim)
print(len(catsim))

catsim = catsim[sel]
plt.close()
xrange = [-1.0, 26.0]
yrange = [-0.5, 2.0]
xlabel = r'$i$ magnitude'
ylabel = r'$r$ - $i$'

corp = corner_plot(
    xrange=xrange, yrange=yrange, bins=30, xlabel=xlabel, ylabel=ylabel,
    xlim=[20, 26], ylim=[-0.5, 2.05]
)

x_array = catsim["i_ab"]
y_array = catsim["g_ab"] - catsim["r_ab"]
weights= catsim["prob"]

x_array_d = des["mag_i"]
y_array_d = des["mag_g"] - des["mag_r"]

corp.make_plot(x_array=x_array_d, y_array=y_array_d, linestyles="-",  levels=[0.1, 0.3, 0.65])
corp.make_plot(x_array=x_array, y_array=y_array, w_array=weights, linestyles="--",  levels=[0.1, 0.3, 0.65])

# %%
plt.hist(des["z"], density=True, histtype="step")
plt.hist(catsim["redshift"], density=True, histtype="step", weights=weights)

# %%
catsim = astTable.Table.read("/work/xiangchong.li/superonionGW/code/image/catsim-v4/OneDegSq.fits")

print(len(catsim))
plt.hist(des["z"], density=True, histtype="step")
plt.hist(catsim["redshift"], density=True, histtype="step", weights=catsim["prob"])
